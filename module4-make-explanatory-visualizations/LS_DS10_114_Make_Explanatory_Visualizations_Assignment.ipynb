# %% [markdown]
# <a href="https://colab.research.google.com/github/maltaro/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module4-make-explanatory-visualizations/LS_DS10_114_Make_Explanatory_Visualizations_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 1, Sprint 1, Module 4*
#
# ---
#
# # ASSIGNMENT
#
# ### 1) Replicate the lesson code. I recommend that you [do not copy-paste](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit).
#
# Get caught up to where we got our example in class and then try and take things further. How close to "pixel perfect" can you make the lecture graph?
#
# Once you have something that you're proud of, share your graph in the cohort channel and move on to the second exercise.
#
# ### 2) Reproduce another example from [FiveThityEight's shared data repository](https://data.fivethirtyeight.com/).
#
# **WARNING**: There are a lot of very custom graphs and tables at the above link. I **highly** recommend not trying to reproduce any that look like a table of values or something really different from the graph types that we are already familiar with. Search through the posts until you find a graph type that you are more or less familiar with: histogram, bar chart, stacked bar chart, line chart, [seaborn relplot](https://seaborn.pydata.org/generated/seaborn.relplot.html), etc. Recreating some of the graphics that 538 uses would be a lot easier in Adobe photoshop/illustrator than with matplotlib.
#
# - If you put in some time to find a graph that looks "easy" to replicate you'll probably find that it's not as easy as you thought.
#
# - If you start with a graph that looks hard to replicate you'll probably run up against a brick wall and be disappointed with your afternoon.

# %%
# Your Work Here

import matplotlib.pyplot as plt

sample_data = [1,4,2,5,3,6]
plt.plot(sample_data)
plt.title("The Title")
plt.xlabel('x label')
plt.ylabel('y label')
plt.show()

more_data = [6,4,5,3,4,2]
plt.plot(more_data)
plt.show()

# %%
fig, ax = plt.subplots()

fig.patch.set(facecolor='green')

ax.plot(sample_data)
ax.set(facecolor="yellow")
ax.set_title("Graph Title")
ax.set_ylabel('my y label')
ax.set_xlabel('my x label')
# Out:
# Text(0.5, 0, 'my x label')

# %%
from IPython.display import display, Image

url = 'https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png'
example = Image(url=url, width=400)

display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png" width="400"/>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd




fake = pd.Series([38, 3, 2, 1, 2, 4, 6, 5, 5, 33], 
                 index=range(1,11))

fake.plot.bar(color='C1', width=0.9);

# %%
# Set stylesheet
plt.style.use('fivethirtyeight')

# figure axes syntax
fig, ax = plt.subplots()

# Make the figure background color white
fig.patch.set(facecolor='white')

# put bars on the axes
fake.plot.bar(width=0.9, color='#ED713A')

# Set axes background color
ax.set(facecolor='white')

# Set plot title
ax.set_title("'An Inconvenient Sequel: truth To Power' is divisive", fontsize=12, fontweight='bold', x=.35, y=1.1) 

# Set plot ylabel
ax.set_ylabel('Percent of total votes', fontsize=9, fontweight='bold')

# Set plot xlabel
ax.set_xlabel('Rating', fontsize=9, fontweight='bold')

# Set subtitle
ax.text(s='IMDb ratings for the film as of Aug. 29', y=41.5, x=-1.8, fontsize=12)

# set y axis labels, tick marks and grid lines
ax.set_yticklabels(['0', '10', '20', '30', '40%'], fontsize=10)
ax.set_yticks(range(0,50,10))

# Set x axis labels, tick marks and grid lines
ax.set_xticklabels(range(1,11,1), rotation='horizontal', fontsize=10)

# Show the plot and squelch the funny output
fig.show()

# %%
from IPython.display import display, Image

url = "https://fivethirtyeight.com/wp-content/uploads/2019/10/Mehta-Media1028-1028-1.png?w=1150"
example = Image(url=url, width=400)

display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2019/10/Mehta-Media1028-1028-1.png?w=1150" width="400"/>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [3.1,3.7,3.25,2.8,3.3,2.6,3.7,4,3,3.5,2.25,1.25,2.25,1.5,1.8,2,1.8,1.6,1.8,2,2.2,1.6,4.7,5,1.7,1.8]
len(x)
# Out:
# 26

# %%
y = [1.2,1.5,1.5,1.5,1.1,1.2,1.6,1.4,1.5,1.7,1.1,1,1.3,0.9,0.9,1.2, 1.3,0.9,0.8,1.1,1.1,1.1,4.7,3,1.4,1.5]
len(y)
# Out:
# 26

# %%
# I create two dataframes with exactly the same amount of datapoints. Then I 
# plot them against np.linspace between 0.5 and 6.5.
cable = pd.Series([3.1,3.7,3.25,2.8,3.3,2.6,3.7,4,3,3.5,2.25,1.25,2.25,1.5,1.8,2,1.8,1.6,1.8,2,2.2,1.6,4.7,5,1.7,1.8], index=np.linspace(0.5,6.5,26))
online = pd.Series([1.2,1.5,1.5,1.5,1.1,1.2,1.6,1.4,1.5,1.7,1.1,1,1.3,0.9,0.9,1.2, 1.3,0.9,0.8,1.1,1.1,1.1,4.7,3,1.4,1.5], index=np.linspace(0.5,6.5,26))
cable.plot()
online.plot();

# %%
# Now it is time to finetune the graph. I will start with the title.

# %%
# defining the stylesheet
plt.style.use('fivethirtyeight')
# defining subplots
fig, ax = plt.subplots()
ax.set_title("Bidens Ukraine-related media bump is fading", fontsize=14, fontweight=500, x=.35, y=1.1) 
# next up is the subtitle
ax.text(s='Bidens share of media of media mentions on each medium relative to the next', y=5.5, x=0.05, fontsize=10, fontweight =400)
ax.text(s="most mentioned candidate each week", y= 5.2, x =0.05, fontsize =10, fontweight =400)
# now the descriptions for the two graphs
ax.text(s="Cable News", x=0.6 , y=3.9, fontsize =12, fontweight = 500)
ax.text(s="Online News", x=0.6, y=1.7, fontsize=12, fontweight=500)
#and the description at the peak of the graph
ax.text(s="After the Ukraine News broke\n Biden was mentioned five times \n more than the next most-mentioned \n candidate on cable news",
x = 3, y= 4.2, fontsize= 9, fontweight= 350)
#time to label the x-axis
ax.set_xticklabels(["","MAY 19", "JUNE" ,"JULY", "AUG:", "SEPT.", "OCT." ], rotation='horizontal', fontsize=10)
#and now the y-axis
ax.set_yticklabels(["",'EVEN', '2', '3', '4', '5x'], fontsize=10)

cable.plot()
online.plot();

# %% [markdown]
# # STRETCH OPTIONS
#
# ### 1) Reproduce one of the following using the matplotlib or seaborn libraries:
#
# - [thanksgiving-2015](https://fivethirtyeight.com/features/heres-what-your-part-of-america-eats-on-thanksgiving/)
# - [candy-power-ranking](https://fivethirtyeight.com/features/the-ultimate-halloween-candy-power-ranking/)
# - or another example of your choice!
#
# ### 2) Make more charts!
#
# Choose a chart you want to make, from [Visual Vocabulary - Vega Edition](http://ft.com/vocabulary).
#
# Find the chart in an example gallery of a Python data visualization library:
# - [Seaborn](http://seaborn.pydata.org/examples/index.html)
# - [Altair](https://altair-viz.github.io/gallery/index.html)
# - [Matplotlib](https://matplotlib.org/gallery.html)
# - [Pandas](https://pandas.pydata.org/pandas-docs/stable/visualization.html)
#
# Reproduce the chart. [Optionally, try the "Ben Franklin Method."](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit) If you want, experiment and make changes.
#
# Take notes. Consider sharing your work with your cohort!

# %%
# More Work Here
